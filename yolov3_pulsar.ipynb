# %%
# !mkdir -p pulsar/pulsar-data
import moxing as mox
import os

from_path_data = 's3://zhouy/yolo/fake_pulsar_test'
to_path2 = '/home/ma-user/work/pulsar/pulsar-data/fake_images/fake_pulsar_test'
cp_data = mox.file.copy_parallel(from_path_data, to_path2)
from_path_data = 's3://zhouy/yolo/fake_pulsar_test_ann.json'
to_path2 = '/home/ma-user/work/pulsar/pulsar-data/annotations/fake_pulsar_test_ann.json'
cp_data = mox.file.copy(from_path_data, to_path2)
# !cd yolov3_pulsar && rm -rf *.ir && rm -rf *.dat && rm -rf *.dot && rm -rf kernel_meta
# !cd yolov3_pulsar && ls

# %%
import moxing as mox
import os

from_path_code = 's3://zhouy/yolo/yolov3_pulsar/train.py'
to_path1 = '/home/ma-user/work/yolov3_pulsar/train.py'
cp_code = mox.file.copy_parallel(from_path_code, to_path1)
print("=====copy from obs=======")
# !cd yolov3_pulsar && python train.py
# Out:
# =====copy from obs=======
# 2021-06-02 06:39:19,904:INFO:Args:
# 2021-06-02 06:39:19,904:INFO:--> device_target: Ascend
# 2021-06-02 06:39:19,904:INFO:--> data_dir: /home/ma-user/work/pulsar/pulsar-data/fake_images/fake_pulsar_train/
# 2021-06-02 06:39:19,904:INFO:--> annFile: /home/ma-user/work/pulsar/pulsar-data/annotations/fake_pulsar_train_ann.json
# 2021-06-02 06:39:19,904:INFO:--> per_batch_size: 8
# 2021-06-02 06:39:19,904:INFO:--> pretrained_backbone:
# 2021-06-02 06:39:19,904:INFO:--> resume_yolov3:
# 2021-06-02 06:39:19,905:INFO:--> lr_scheduler: exponential
# 2021-06-02 06:39:19,905:INFO:--> lr: 0.001
# 2021-06-02 06:39:19,905:INFO:--> lr_epochs: [30, 45]
# 2021-06-02 06:39:19,905:INFO:--> lr_gamma: 0.1
# 2021-06-02 06:39:19,905:INFO:--> eta_min: 0.0
# 2021-06-02 06:39:19,905:INFO:--> T_max: 60
# 2021-06-02 06:39:19,905:INFO:--> max_epoch: 60
# 2021-06-02 06:39:19,905:INFO:--> warmup_epochs: 0
# 2021-06-02 06:39:19,905:INFO:--> weight_decay: 0.0005
# ...

# %%
# !cd yolov3_pulsar && rm -rf *.ir && rm -rf *.dat && rm -rf *.dot && rm -rf kernel_meta && rm -rf *.pb
# !ls yolov3_pulsar/
# Out:
# eval.py  outputs  README.md  scripts  src  train.py

# %%
import moxing as mox
import os

from_path_code = '/home/ma-user/work/yolov3_pulsar'
to_path1 = 's3://zhouy/yolo/yolov3_pulsar'
cp_code = mox.file.copy_parallel(from_path_code, to_path1)

# %%
import moxing as mox
import os

from_path_code = 's3://zhouy/yolo/yolov3_pulsar/eval.py'
to_path1 = '/home/ma-user/work/yolov3_pulsar/eval.py'
cp_code = mox.file.copy_parallel(from_path_code, to_path1)
print("=====copy from obs=======")
# !cd yolov3_pulsar && python eval.py
# Out:
# =====copy from obs=======
# 2021-06-02 09:34:13,659:INFO:Creating Network....
# 2021-06-02 09:34:15,471:INFO:/home/ma-user/work/yolov3_pulsar/outputs/2021-06-02_time_06_39_19/ckpt_0/0-60_15000.ckpt
# 2021-06-02 09:34:17,098:INFO:load_model /home/ma-user/work/yolov3_pulsar/outputs/2021-06-02_time_06_39_19/ckpt_0/0-60_15000.ckpt success
# 2021-06-02 09:34:17,115:INFO:testing shape : [224, 3840]
# 2021-06-02 09:34:17,115:INFO:total 200 images to eval
# 2021-06-02 09:34:17,124:INFO:Start inference....
# [WARNING] PRE_ACT(71817,python):2021-06-02-09:34:35.100.184 [mindspore/ccsrc/backend/optimizer/common/helper.cc:372] CreateTupleTensor] The value 0xaaab41f045a0of tuple is not a scalar
# [WARNING] PRE_ACT(71817,python):2021-06-02-09:34:35.100.224 [mindspore/ccsrc/backend/optimizer/pass/convert_const_input_to_tensor_input.cc:49] CreateTensorInput] Create tensor failed
# ...

# %%
import moxing as mox
import os

from_path_data = 's3://zhouy/yolo/fake_pulsar_test_2'
to_path2 = '/home/ma-user/work/pulsar/pulsar-data/fake_images/fake_pulsar_test_2'
cp_data = mox.file.copy_parallel(from_path_data, to_path2)
